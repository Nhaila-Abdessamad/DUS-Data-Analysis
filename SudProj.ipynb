# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

sudPath = r"C:\Users\NAILAS\Desktop\PFE\INPT\Data\sud.csv"
sudData = pd.read_csv(sudPath)
sudData.describe()
# Out:
#               N°  Année du baccalauréat    SUD 111    SUD 112    SUD 113  \
# count  38.000000              38.000000  38.000000  38.000000  38.000000
# mean   19.500000            2015.605263  14.223684  13.815789  13.934211
# std    11.113055               0.718086   2.662800   2.634032   2.131397
# min     1.000000            2014.000000   9.000000  10.000000   9.000000
# 25%    10.250000            2015.250000  12.250000  12.000000  12.500000
# 50%    19.500000            2016.000000  14.000000  13.500000  14.000000
# 75%    28.750000            2016.000000  16.000000  15.375000  15.000000
# max    38.000000            2016.000000  19.500000  19.500000  18.000000
#
#           SUD 11    SUD 121    SUD 122    SUD 123     SUD 12  ...     SUD541  \
# count  38.000000  38.000000  38.000000  38.000000  38.000000  ...  33.000000
# mean   13.942632  15.039474  14.986842  13.828947  14.617632  ...  11.560606
# std     2.018404   2.505080   2.621988   2.741760   1.748062  ...   7.254048
# ...

# %%
sudData
# Out:
#     N° Première Inscription  \
# 0    1            2018-2019
# 1    2            2018-2019
# 2    3            2018-2019
# 3    4            2018-2019
# 4    5            2018-2019
# 5    6            2018-2019
# 6    7            2018-2019
# 7    8            2018-2019
# 8    9            2018-2019
# 9   10            2018-2019
# 10  11            2018-2019
# 11  12            2018-2019
# 12  13            2018-2019
# 13  14            2018-2019
# 14  15            2018-2019
# 15  16            2018-2019
# 16  17            2018-2019
# 17  18            2018-2019
# 18  19            2018-2019
# 19  20            2018-2019
# 20  21            2018-2019
# 21  22            2018-2019
# 22  23            2018-2019
# 23  24            2018-2019
# 24  25            2018-2019
# 25  26            2018-2019
# 26  27            2018-2019
# 27  28            2018-2019
# 28  29            2018-2019
# 29  30            2018-2019
# 30  31            2018-2019
# 31  32            2018-2019
# ...

# %%
sudData.head()
# Out:
#    N° Première Inscription                                   Filière Affectée  \
# 0   1            2018-2019  INGÉNIERIE DES SYSTÈMES UBIQUITAIRES ET DISTRI...
# 1   2            2018-2019  INGÉNIERIE DES SYSTÈMES UBIQUITAIRES ET DISTRI...
# 2   3            2018-2019  INGÉNIERIE DES SYSTÈMES UBIQUITAIRES ET DISTRI...
# 3   4            2018-2019  INGÉNIERIE DES SYSTÈMES UBIQUITAIRES ET DISTRI...
# 4   5            2018-2019  INGÉNIERIE DES SYSTÈMES UBIQUITAIRES ET DISTRI...
#
#   Genre Nationalité  Année du baccalauréat  \
# 0     M   Marocaine                   2016
# 1     M   Marocaine                   2016
# 2     M   Marocaine                   2014
# 3     M   Marocaine                   2016
# 4     F   Marocaine                   2016
#
#                       Série du baccalauréat Mention du baccalauréat  \
# 0               SM : Sciences Mathématiques              Assez Bien
# 1               SM : Sciences Mathématiques               Très Bien
# ...

# %%
sudData.columns
# Out:
# Index(['N°', 'Première Inscription', 'Filière Affectée', 'Genre',
#        'Nationalité', 'Année du baccalauréat', 'Série du baccalauréat',
#        'Mention du baccalauréat', 'Filière CNC', 'Classement CNC',
#        ...
#        'V/R.15', 'SUD551', 'SUD552', 'SUD55', 'V/R.16', 'SUD561', 'SUD562',
#        'SUD56', 'V/R.17', 'Moy S5'],
#       dtype='object', length=162)

# %% [markdown]
# # 1.There Is 4 Backgrounds: Which Backgrund Performs The Best??

# %%
my_tab = pd.crosstab(index = sudData["Filière CNC"],  # Make a crosstab
                              columns="Filière CNC")      # Name the count column

my_tab.plot.bar()
# Out:
# <AxesSubplot:xlabel='Filière CNC'>

# %%
sudData.boxplot(column="Moy S5",        # Column to plot
                 by= "Filière CNC",         # Column to split upon
                 figsize= (6,6))        # Figure size
# Out:
# <AxesSubplot:title={'center':'Moy S5'}, xlabel='Filière CNC'>

# %%
sudData.boxplot(column="MOY S4",        # Column to plot
                 by= "Filière CNC",         # Column to split upon
                 figsize= (6,6))
# Out:
# <AxesSubplot:title={'center':'MOY S4'}, xlabel='Filière CNC'>

# %%
sudData.boxplot(column="MOY S3",        # Column to plot
                 by= "Filière CNC",         # Column to split upon
                 figsize= (6,6))
# Out:
# <AxesSubplot:title={'center':'MOY S3'}, xlabel='Filière CNC'>

# %%
sudData.boxplot(column="Moy S2",        # Column to plot
                 by= "Filière CNC",         # Column to split upon
                 figsize= (6,6))
# Out:
# <AxesSubplot:title={'center':'Moy S2'}, xlabel='Filière CNC'>

# %%
sudData.boxplot(column="Moy S1",        # Column to plot
                 by= "Filière CNC",         # Column to split upon
                 figsize= (6,6))
# Out:
# <AxesSubplot:title={'center':'Moy S1'}, xlabel='Filière CNC'>

# %% [markdown]
# # 2.Male vs Female Academic Performance?(Agreabelness JP)

# %%
sudData.boxplot(column="Moy S1",        # Column to plot
                 by= "Genre",         # Column to split upon
                 figsize= (6,6))
# Out:
# <AxesSubplot:title={'center':'Moy S1'}, xlabel='Genre'>

# %%
sudData.boxplot(column="Moy S2",        # Column to plot
                 by= "Genre",         # Column to split upon
                 figsize= (6,6))
# Out:
# <AxesSubplot:title={'center':'Moy S2'}, xlabel='Genre'>

# %%
sudData.boxplot(column="MOY S3",        # Column to plot
                 by= "Genre",         # Column to split upon
                 figsize= (6,6))
# Out:
# <AxesSubplot:title={'center':'MOY S3'}, xlabel='Genre'>

# %%
sudData.boxplot(column="MOY S4",        # Column to plot
                 by= "Genre",         # Column to split upon
                 figsize= (6,6))
# Out:
# <AxesSubplot:title={'center':'MOY S4'}, xlabel='Genre'>

# %%
sudData.boxplot(column="Moy S5",        # Column to plot
                 by= "Genre",         # Column to split upon
                 figsize= (6,6))
# Out:
# <AxesSubplot:title={'center':'Moy S5'}, xlabel='Genre'>
