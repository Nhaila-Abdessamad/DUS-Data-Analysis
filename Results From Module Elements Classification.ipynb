# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

sudPath = r"C:\Users\NAILAS\Desktop\B1--PFE\0. The Project\2.Data\sud.csv"
sudData = pd.read_csv(sudPath)
sudData.describe()
# Out:
#               N°  Année du baccalauréat     SUD111     SUD112     SUD113  \
# count  38.000000              38.000000  38.000000  38.000000  38.000000
# mean   19.500000            2015.605263  14.223684  13.815789  13.934211
# std    11.113055               0.718086   2.662800   2.634032   2.131397
# min     1.000000            2014.000000   9.000000  10.000000   9.000000
# 25%    10.250000            2015.250000  12.250000  12.000000  12.500000
# 50%    19.500000            2016.000000  14.000000  13.500000  14.000000
# 75%    28.750000            2016.000000  16.000000  15.375000  15.000000
# max    38.000000            2016.000000  19.500000  19.500000  18.000000
#
#            SUD11     SUD121     SUD122     SUD123      SUD12  ...     SUD541  \
# count  38.000000  38.000000  38.000000  38.000000  38.000000  ...  33.000000
# mean   13.942632  15.039474  14.986842  13.828947  14.617632  ...  11.560606
# std     2.018404   2.505080   2.621988   2.741760   1.748062  ...   7.254048
# ...

# %%
sudData.columns
# Out:
# Index(['N°', 'Première Inscription', 'Filière Affectée', 'Genre',
#        'Nationalité', 'Année du baccalauréat', 'Série du baccalauréat',
#        'Mention du baccalauréat', 'Filière CNC', 'Classement CNC',
#        ...
#        'V/R.15', 'SUD551', 'SUD552', 'SUD55', 'V/R.16', 'SUD561', 'SUD562',
#        'SUD56', 'V/R.17', 'Moy S5'],
#       dtype='object', length=162)

# %% [markdown]
# # Creation Of The Dataframes Required for Analysis:

# %%
#df for Data Modulue Elements:
data_df = sudData[['Filière CNC','SUD112','SUD141','SUD142','SUD241','SUD242','SUD423','SUD433','SUD441','SUD442','SUD443','SUD521','SUD522']]

#df for Devops Modulue Elements:
devops_df = sudData[['Filière CNC','SUD213','SUD511','SUD413','SUD421','SUD422','SUD512']]

#df for iot Modulue Elements:
iot_df = sudData[['Filière CNC','SUD323','SUD333','SUD341','SUD342','SUD343','SUD431','SUD432','SUD511','SUD531','SUD532']]

#df for shl Modulue Elements:
shl_df = sudData[['Filière CNC','SUD113','SUD143','SUD211','SUD212','SUD221','SUD222','SUD243','SUD311','SUD312','SUD313','SUD412','SUD321','SUD411','SUD433']]

#df for sll Modulue Elements:#df for Data Modulue Elements:
sll_df = sudData[['Filière CNC','SUD121','SUD111','SUD212','SUD221','SUD122','SUD232','SUD123','SUD322']]

#df for na Modulue Elements:
na_df = sudData[['Filière CNC','SUD131','SUD132','SUD133','SUD231','SUD233','SUD331']]

# %% [markdown]
# # Does The CNC Background Impact the Elements Performance?

# %% [markdown]
# ## The Data Class

# %%
#Data

data_df.head()
# Out:
#   Filière CNC  SUD112  SUD141  SUD142  SUD241  SUD242  SUD423  SUD433  SUD441  \
# 0          MP    10.5    14.0   11.00    11.5     4.0    15.0    18.5    15.0
# 1          MP    13.5    11.0    9.75    12.0    11.5    15.5    11.0    17.0
# 2         TSI    14.0    14.0   13.50    12.0     9.0    15.5    15.5    16.0
# 3         PSI    16.0     8.0   11.25    15.5    16.5    15.0    10.5    15.0
# 4          MP    10.0    14.0   14.50    10.0    15.0    12.5    16.5    16.0
#
#    SUD442  SUD443  SUD521  SUD522
# 0    15.2    17.0    12.5   19.50
# 1    13.5    16.5    18.0   15.75
# 2    15.2    17.0    13.5   15.50
# 3    16.4    13.0    16.0   16.50
# 4    14.7    15.5    15.5   18.50

# %%
data_df.describe()
# Out:
#           SUD112     SUD141     SUD142     SUD241     SUD242     SUD423  \
# count  38.000000  38.000000  38.000000  38.000000  38.000000  38.000000
# mean   13.815789  12.723684  11.052632  13.138158  11.131579  14.000000
# std     2.634032   2.767322   2.666204   2.017405   4.033113   1.133042
# min    10.000000   7.000000   5.000000  10.000000   4.000000  12.500000
# 25%    12.000000  11.000000   9.500000  11.625000   7.625000  13.000000
# 50%    13.500000  13.000000  11.000000  12.625000  11.000000  14.500000
# 75%    15.375000  14.500000  12.937500  14.375000  14.875000  15.000000
# max    19.500000  18.000000  17.000000  17.500000  17.500000  15.500000
#
#           SUD433     SUD441     SUD442     SUD443     SUD521     SUD522
# count  38.000000  38.000000  38.000000  38.000000  33.000000  33.000000
# mean   16.078947  15.447368  16.042105  16.157895  14.545455  16.825758
# std     3.766004   1.413207   1.663622   2.342629   2.884126   2.426646
# ...

# %%
data_df.columns
# Out:
# Index(['Filière CNC', 'SUD112', 'SUD141', 'SUD142', 'SUD241', 'SUD242',
#        'SUD423', 'SUD433', 'SUD441', 'SUD442', 'SUD443', 'SUD521', 'SUD522'],
#       dtype='object')

# %%
correlations = data_df.corr()
sns.heatmap(correlations)
plt.show()

# %%
 data_df.corr(method='pearson', min_periods=1)
# Out:
#           SUD112    SUD141    SUD142    SUD241    SUD242    SUD423    SUD433  \
# SUD112  1.000000  0.142068  0.251566  0.430879  0.092659 -0.147158 -0.045493
# SUD141  0.142068  1.000000  0.226387  0.204298  0.002740  0.030169  0.160991
# SUD142  0.251566  0.226387  1.000000  0.427597  0.591562  0.063745  0.514696
# SUD241  0.430879  0.204298  0.427597  1.000000  0.490568  0.248301  0.285335
# SUD242  0.092659  0.002740  0.591562  0.490568  1.000000  0.192219  0.437033
# SUD423 -0.147158  0.030169  0.063745  0.248301  0.192219  1.000000  0.373700
# SUD433 -0.045493  0.160991  0.514696  0.285335  0.437033  0.373700  1.000000
# SUD441  0.046334 -0.067745  0.565627  0.110452  0.380599  0.194108  0.441337
# SUD442  0.231873  0.152736  0.215493  0.057207  0.137720  0.194284  0.319972
# SUD443  0.010316  0.066321  0.562244  0.091049  0.314551  0.356383  0.684001
# SUD521  0.074056 -0.164814  0.462085  0.288716  0.572608  0.266071  0.593036
# ...

# %%
data_df.cov(min_periods=None, ddof=1)
# Out:
#           SUD112    SUD141    SUD142    SUD241     SUD242    SUD423  \
# SUD112  6.938122  1.035562  1.766714  2.289651   0.984353 -0.439189
# SUD141  1.035562  7.658073  1.670341  1.140558   0.030583  0.094595
# SUD142  1.766714  1.670341  7.108642  2.299964   6.361131  0.192568
# SUD241  2.289651  1.140558  2.299964  4.069924   3.991465  0.567568
# SUD242  0.984353  0.030583  6.361131  3.991465  16.266003  0.878378
# SUD423 -0.439189  0.094595  0.192568  0.567568   0.878378  1.283784
# SUD433 -0.451280  1.677809  5.168030  2.167852   6.637980  1.594595
# SUD441  0.172475 -0.264936  2.131223  0.314900   2.169275  0.310811
# SUD442  1.016074  0.703165  0.955832  0.191999   0.924040  0.366216
# SUD443  0.063656  0.429943  3.511735  0.430299   2.971906  0.945946
# SUD521  0.586648 -1.289062  3.624290  1.687855   6.744318  0.873580
# SUD522 -0.044389  0.432292  3.815874  0.661399   3.503551  0.325758
#
#            SUD433    SUD441    SUD442    SUD443    SUD521    SUD522
# ...

# %% [markdown]
# ### INDIVIDUAL ELEMENTS STUDY :

# %% [markdown]
# ### Data Elements:

# %% [markdown]
# #### Relational Data Bases and ORM:

# %%
a=data_df.boxplot(column="SUD112",        # Column to plot
                 by= "Filière CNC",         # Column to split upon
                 figsize= (4.5,4.5)) # Figure size

# %%
sns.histplot(data=data_df["SUD112"],stat='count',discrete=True)
# Out:
# <AxesSubplot:xlabel='SUD112', ylabel='Count'>

# %% [markdown]
# #### Maths For Engineering:

# %%
data_df.boxplot(column="SUD141",        
                 by= "Filière CNC",         
                 figsize= (4.5,4.5))
# Out:
# <AxesSubplot:title={'center':'SUD141'}, xlabel='Filière CNC'>

# %%
sns.histplot(data=data_df["SUD141"],stat='count',discrete=True)
# Out:
# <AxesSubplot:xlabel='SUD141', ylabel='Count'>

# %% [markdown]
# #### Probability And Statistics:

# %%
data_df.boxplot(column="SUD142",        
                 by= "Filière CNC",         
                 figsize= (4.5,4.5))
# Out:
# <AxesSubplot:title={'center':'SUD142'}, xlabel='Filière CNC'>

# %%
sns.histplot(data=data_df["SUD142"],stat='count',discrete=True)
# Out:
# <AxesSubplot:xlabel='SUD142', ylabel='Count'>

# %% [markdown]
# #### Linear and Non-Linear Optimization:

# %%
data_df.boxplot(column="SUD241",        
                 by= "Filière CNC",         
                 figsize= (5,5))
# Out:
# <AxesSubplot:title={'center':'SUD241'}, xlabel='Filière CNC'>

# %%
sns.histplot(data=data_df["SUD241"],stat='count',discrete=True)
# Out:
# <AxesSubplot:xlabel='SUD241', ylabel='Count'>

# %% [markdown]
# #### Graph theory and scheduling:

# %%
data_df.boxplot(column="SUD242",        
                 by= "Filière CNC",         
                 figsize= (5,5))
# Out:
# <AxesSubplot:title={'center':'SUD242'}, xlabel='Filière CNC'>

# %%
sns.histplot(data=data_df["SUD242"],stat='count',discrete=True)
# Out:
# <AxesSubplot:xlabel='SUD242', ylabel='Count'>

# %% [markdown]
# #### Data centers, Services and Storage Networks:

# %%
data_df.boxplot(column="SUD423",        
                 by= "Filière CNC",         
                 figsize= (5,5))
# Out:
# <AxesSubplot:title={'center':'SUD423'}, xlabel='Filière CNC'>

# %%
sns.histplot(data=data_df["SUD423"],stat='count',discrete=True)
# Out:
# <AxesSubplot:xlabel='SUD423', ylabel='Count'>

# %% [markdown]
# #### NoSQL Databases and ODM.:

# %%
data_df.boxplot(column="SUD433",        
                 by= "Filière CNC",         
                 figsize= (4.5,4.5))
# Out:
# <AxesSubplot:title={'center':'SUD433'}, xlabel='Filière CNC'>

# %%
sns.histplot(data=data_df["SUD433"],stat='count',discrete=True)
# Out:
# <AxesSubplot:xlabel='SUD433', ylabel='Count'>

# %% [markdown]
# #### Pattern Recognition and Machine Learning:

# %%
data_df.boxplot(column="SUD441",        
                 by= "Filière CNC",         
                 figsize= (5,5))
# Out:
# <AxesSubplot:title={'center':'SUD441'}, xlabel='Filière CNC'>

# %%
sns.histplot(data=data_df["SUD441"],stat='count',discrete=True)
# Out:
# <AxesSubplot:xlabel='SUD441', ylabel='Count'>

# %% [markdown]
# #### Data Mining And warehousing:

# %%
data_df.boxplot(column="SUD442",        
                 by= "Filière CNC",         
                 figsize= (4.5,4.5))
# Out:
# <AxesSubplot:title={'center':'SUD442'}, xlabel='Filière CNC'>

# %%
sns.histplot(data=data_df["SUD442"],stat='count',discrete=True)
# Out:
# <AxesSubplot:xlabel='SUD442', ylabel='Count'>

# %% [markdown]
# #### PPP4:

# %%
data_df.boxplot(column="SUD443",        
                 by= "Filière CNC",         
                 figsize= (4.5,4.5))
# Out:
# <AxesSubplot:title={'center':'SUD443'}, xlabel='Filière CNC'>

# %%
sns.histplot(data=data_df["SUD443"],stat='count',discrete=True)
# Out:
# <AxesSubplot:xlabel='SUD443', ylabel='Count'>

# %% [markdown]
# #### Big Data Analytics using R/SCALLA/MADLIB:

# %%
data_df.boxplot(column="SUD521",        
                 by= "Filière CNC",         
                 figsize= (4.5,4.5))
# Out:
# <AxesSubplot:title={'center':'SUD521'}, xlabel='Filière CNC'>

# %%
sns.histplot(data=data_df["SUD521"],stat='count',discrete=True)
# Out:
# <AxesSubplot:xlabel='SUD521', ylabel='Count'>

# %% [markdown]
# #### Distributed Big Data Processing Using MapReduce/Hadoop/Kafka:

# %%
data_df.boxplot(column="SUD522",        
                 by= "Filière CNC",         
                 figsize= (4.5,4.5))
# Out:
# <AxesSubplot:title={'center':'SUD522'}, xlabel='Filière CNC'>

# %%
sns.histplot(data=data_df["SUD522"],stat='count',discrete=True)
# Out:
# <AxesSubplot:xlabel='SUD522', ylabel='Count'>

# %% [markdown]
# ## The Devops Class

# %%
devops_df.head()
# Out:
#   Filière CNC  SUD213  SUD511  SUD413  SUD421  SUD422  SUD512
# 0          MP   10.25    18.5    11.0    14.0   11.75   11.50
# 1          MP   11.00     NaN    11.0    15.0   14.00   10.75
# 2         TSI   13.00     NaN    14.0    17.0   15.25   11.25
# 3         PSI   14.75    16.0    15.0    11.0   11.00   14.50
# 4          MP   17.50    14.0    13.0    15.0   14.25   16.50

# %%
devops_df.describe()
# Out:
#           SUD213     SUD511     SUD413     SUD421     SUD422     SUD512
# count  38.000000  23.000000  38.000000  38.000000  38.000000  33.000000
# mean   14.881579  15.434783  12.868421  14.684211  13.671053  12.212121
# std     3.158930   2.096015   2.338526   1.932723   1.972878   5.992222
# min     8.250000  12.500000   8.000000  11.000000  11.000000   0.000000
# 25%    12.562500  13.500000  11.000000  14.000000  12.000000  11.250000
# 50%    15.000000  16.000000  13.000000  15.000000  14.000000  13.750000
# 75%    17.500000  16.500000  15.000000  16.000000  15.000000  16.750000
# max    20.000000  18.500000  17.000000  18.000000  17.500000  18.500000

# %%
correlations = devops_df.corr()
sns.heatmap(correlations)
plt.show()

# %%
L=['SUD213','SUD511','SUD413','SUD421','SUD422','SUD512']
for i in range(len(L)):
    devops_df.boxplot(column=L[i],        
                 by= "Filière CNC",         
                 figsize= (4.5,4.5))

# %%
L=['SUD213','SUD511','SUD413','SUD421','SUD422','SUD512']
for i in range(len(L)):
    sns.histplot(data=devops_df[L[i]],stat='count',discrete=True)
    plt.show()

# %% [markdown]
# ## The iot Class

# %%
iot_df.head()
# Out:
#   Filière CNC  SUD323  SUD333  SUD341  SUD342  SUD343  SUD431  SUD432  SUD511  \
# 0          MP     8.4    17.5   15.35   11.20   11.25    17.0   17.00    18.5
# 1          MP    10.0    16.0   16.34   12.15   11.00    14.0   15.00     NaN
# 2         TSI    11.5    16.0   10.23   12.00   12.00    14.0   14.75     NaN
# 3         PSI    15.4    16.0   15.84   17.20   15.75    17.0   15.50    16.0
# 4          MP    12.2    16.5   15.35   15.15   14.25    14.0   14.75    14.0
#
#    SUD531  SUD532
# 0    15.0    17.0
# 1    13.0    16.0
# 2    14.5    17.5
# 3    15.0    17.0
# 4    12.0    16.5

# %%
iot_df.describe()
# Out:
#           SUD323     SUD333     SUD341     SUD342     SUD343     SUD431  \
# count  38.000000  38.000000  38.000000  38.000000  38.000000  38.000000
# mean   12.513158  16.723684  15.257632  13.651316  13.677632  15.947368
# std     2.822992   1.634499   1.927386   3.193670   3.060156   2.837465
# min     7.000000  12.000000   8.580000   7.000000   8.000000  11.000000
# 25%    10.850000  16.000000  15.222500  11.312500  11.375000  14.000000
# 50%    12.900000  16.500000  15.350000  13.375000  13.250000  17.000000
# 75%    14.575000  18.000000  16.580000  16.487500  16.375000  18.500000
# max    17.800000  19.000000  17.490000  19.250000  18.750000  19.500000
#
#           SUD432     SUD511     SUD531     SUD532
# count  38.000000  23.000000  33.000000  33.000000
# mean   15.157895  15.434783  14.227273  16.530303
# std     2.428311   2.096015   3.670173   1.060214
# min     8.000000  12.500000   0.000000  14.000000
# 25%    14.500000  13.500000  12.000000  16.000000
# ...

# %%
correlations = iot_df.corr()
sns.heatmap(correlations)
plt.show()

# %%
L=['SUD323','SUD333','SUD341','SUD342','SUD343','SUD431','SUD432','SUD511','SUD531','SUD532']
for i in range(len(L)):
    iot_df.boxplot(column=L[i],        
                 by= "Filière CNC",         
                 figsize= (4.5,4.5))

# %%
for i in range(len(L)):
    sns.histplot(data=iot_df[L[i]],stat='count',discrete=True)
    plt.show()

# %% [markdown]
# ## The SHL Class

# %%
shl_df.head()
# Out:
#   Filière CNC  SUD113  SUD143  SUD211  SUD212  SUD221  SUD222  SUD243  SUD311  \
# 0          MP    13.5    15.5    13.5    13.0    0.00    0.00     0.0    15.0
# 1          MP    10.5    15.5    11.0     7.5   12.66   13.67    14.5    16.0
# 2         TSI    14.0    15.0     6.0    13.0   13.34   13.33    15.0    16.0
# 3         PSI    13.5    15.5    19.5    10.0   14.66   18.00    16.0    16.0
# 4          MP    12.5    14.0    12.5    11.5   13.00   15.67    16.5    15.5
#
#    SUD312  SUD313  SUD412  SUD321  SUD411  SUD433
# 0    13.0    16.0    17.0    15.0    14.0    18.5
# 1    13.0    17.0    12.0    11.0    14.0    11.0
# 2    14.0    16.4    17.0    15.0    17.0    15.5
# 3    16.5    12.7    12.0    18.0    12.0    10.5
# 4    14.7    15.2    17.0    14.0    16.0    16.5

# %%
shl_df.describe()
# Out:
#           SUD113     SUD143     SUD211     SUD212     SUD221     SUD222  \
# count  38.000000  38.000000  38.000000  38.000000  38.000000  38.000000
# mean   13.934211  15.289474  10.723684  10.368421  13.631842  14.316316
# std     2.131397   1.148628   2.928650   2.426443   2.583417   3.171657
# min     9.000000  14.000000   6.000000   6.500000   0.000000   0.000000
# 25%    12.500000  14.000000   9.000000   8.625000  13.000000  13.330000
# 50%    14.000000  15.500000  10.500000  10.000000  13.665000  14.165000
# 75%    15.000000  15.875000  12.500000  12.375000  14.670000  16.000000
# max    18.000000  18.000000  19.500000  18.000000  16.340000  19.000000
#
#           SUD243     SUD311     SUD312     SUD313     SUD412     SUD321  \
# count  38.000000  38.000000  38.000000  38.000000  38.000000  38.000000
# mean   15.539474  15.052632  14.297368  15.956579  15.815789  14.342105
# std     2.980526   1.550020   2.193139   2.124763   2.380725   2.275324
# ...

# %%
correlations = shl_df.corr()
sns.heatmap(correlations)
plt.show()

# %%
L=['SUD113','SUD143','SUD211','SUD212','SUD221','SUD222','SUD243','SUD311','SUD312','SUD313','SUD412','SUD321','SUD411','SUD433']
for i in range(len(L)):
    shl_df.boxplot(column=L[i],        
                 by= "Filière CNC",         
                 figsize= (4.5,4.5))

# %%
for i in range(len(L)):
    sns.histplot(data=shl_df[L[i]],stat='count',discrete=True)
    plt.show()

# %% [markdown]
# ## The SLL Class

# %%
sll_df.head()
# Out:
#   Filière CNC  SUD121  SUD111  SUD212  SUD221  SUD122  SUD232  SUD123  SUD322
# 0          MP    13.5     9.0    13.0    0.00   13.50    3.00     6.0    10.0
# 1          MP    11.5    10.5     7.5   12.66   13.50   11.25    10.0    12.0
# 2         TSI    16.0    11.0    13.0   13.34   15.00   10.00    12.5     9.0
# 3         PSI    15.5    11.0    10.0   14.66    9.50    9.50    15.0    16.0
# 4          MP    15.5    11.0    11.5   13.00   12.75   13.50    14.0    11.0

# %%
sll_df.describe()
# Out:
#           SUD121     SUD111     SUD212     SUD221     SUD122     SUD232  \
# count  38.000000  38.000000  38.000000  38.000000  38.000000  38.000000
# mean   15.039474  14.223684  10.368421  13.631842  14.986842  12.919737
# std     2.505080   2.662800   2.426443   2.583417   2.621988   2.971862
# min     9.000000   9.000000   6.500000   0.000000   9.250000   3.000000
# 25%    14.250000  12.250000   8.625000  13.000000  13.500000  11.312500
# 50%    15.750000  14.000000  10.000000  13.665000  14.875000  13.375000
# 75%    16.375000  16.000000  12.375000  14.670000  17.187500  14.687500
# max    18.000000  19.500000  18.000000  16.340000  19.250000  18.000000
#
#           SUD123     SUD322
# count  38.000000  38.000000
# mean   13.828947  11.592105
# std     2.741760   2.743186
# min     6.000000   5.000000
# 25%    12.000000  10.000000
# 50%    14.000000  11.750000
# 75%    15.875000  14.000000
# max    18.500000  16.500000

# %%
correlations = sll_df.corr()
sns.heatmap(correlations)
plt.show()

# %%
L=['SUD121','SUD111','SUD212','SUD221','SUD122','SUD232','SUD123','SUD322']
for i in range(len(L)):
    sll_df.boxplot(column=L[i],        
                 by= "Filière CNC",         
                 figsize= (4.5,4.5))

# %%
for i in range(len(L)):
    sns.histplot(data=sll_df[L[i]],stat='count',discrete=True)
    plt.show()

# %% [markdown]
# ## The NA Class

# %%
na_df.head()
# Out:
#   Filière CNC  SUD131  SUD132  SUD133  SUD231  SUD233  SUD331
# 0          MP    13.5   16.00     8.0     0.0     0.0    14.5
# 1          MP    14.0   15.75     7.0    12.0    10.0    16.0
# 2         TSI    12.0   15.00    10.0     9.5    14.0    12.0
# 3         PSI    14.0   16.50    11.0    14.0    18.0    16.0
# 4          MP    14.5   16.50    10.0    12.0    13.0    14.0

# %%
na_df.describe()
# Out:
#           SUD131     SUD132     SUD133     SUD231     SUD233     SUD331
# count  38.000000  38.000000  38.000000  38.000000  38.000000  38.000000
# mean   14.447368  15.565789   9.539474  11.973684  14.118421  13.986842
# std     1.643124   2.034071   2.494268   4.157291   4.039391   2.577152
# min    11.000000  11.500000   5.500000   0.000000   0.000000   9.000000
# 25%    13.500000  14.500000   7.500000   8.750000  12.000000  12.000000
# 50%    14.500000  15.625000   9.500000  12.250000  14.000000  14.250000
# 75%    15.500000  17.000000  11.375000  15.500000  18.000000  16.000000
# max    17.500000  19.750000  15.500000  17.500000  19.000000  18.000000

# %%
correlations = na_df.corr()
sns.heatmap(correlations)
plt.show()

# %%
L=['SUD131','SUD132','SUD133','SUD231','SUD233','SUD331']
for i in range(len(L)):
    na_df.boxplot(column=L[i],        
                 by= "Filière CNC",         
                 figsize= (4.5,4.5))

# %%
for i in range(len(L)):
    sns.histplot(data=na_df[L[i]],stat='count',discrete=True)
    plt.show()
